# %%
import numpy as np
import random

# %%
car_brands = ["Toyota", "Honda", "Ford", "BMW", "Tesla"]

car_models = {
    "Toyota": ["Camry", "Corolla", "RAV4"],
    "Honda": ["Civic", "Accord", "CR-V"],
    "Ford": ["Fiesta", "Focus", "Explorer"],
    "BMW": ["X3", "X5", "3 Series"],
    "Tesla": ["Model 3", "Model S", "Model X"]
}

car_prices = {
    "Camry": 25000, "Corolla": 20000, "RAV4": 30000,
    "Civic": 22000, "Accord": 26000, "CR-V": 28000,
    "Fiesta": 18000, "Focus": 20000, "Explorer": 35000,
    "X3": 42000, "X5": 55000, "3 Series": 48000,
    "Model 3": 40000, "Model S": 80000, "Model X": 90000
}

# %%
dtype = np.dtype([
    ("CustomerID", "int32"),
    ("CarName", "U20"),
    ("CarModel", "U20"),
    ("Units", "int32"),
    ("Amount", "float64")
])

# %%
dataset = np.zeros(100, dtype=dtype)

for i in range(100):
    brand = random.choice(car_brands)
    model = random.choice(car_models[brand])
    units = random.randint(1, 5)

    dataset[i] = (
        i + 1,
        brand,
        model,
        units,
        units * car_prices[model]
    )

# %%
dataset[:10]
# Out:
# array([( 1, 'Toyota', 'Camry', 4, 100000.), ( 2, 'BMW', 'X3', 5, 210000.),
#        ( 3, 'Ford', 'Fiesta', 2,  36000.),
#        ( 4, 'BMW', '3 Series', 3, 144000.),
#        ( 5, 'Honda', 'Civic', 5, 110000.),
#        ( 6, 'Tesla', 'Model 3', 3, 120000.),
#        ( 7, 'BMW', '3 Series', 4, 192000.),
#        ( 8, 'Tesla', 'Model 3', 5, 200000.),
#        ( 9, 'BMW', 'X3', 4, 168000.), (10, 'Honda', 'Accord', 1,  26000.)],
#       dtype=[('CustomerID', '<i4'), ('CarName', '<U20'), ('CarModel', '<U20'), ('Units', '<i4'), ('Amount', '<f8')])

# %%
dataset = np.zeros(100, dtype=dtype)


#Generate 100 customer IDs starting from 1001.
customer_ids = range(1001, 1101)   # 1001 to 1100

for i, cust_id in enumerate(customer_ids):

    #Randomly assign a car brand to each record.
    brand = random.choice(car_brands)
    
    #Based on the brand, pick a model randomly.
    model = random.choice(car_models[brand])
    
    #Generate units sold between 1 and 5.
    units = random.randint(1, 5)
    
    #Calculate Amount = Units × Model Price.
    amount = units * car_prices[model]
    
    #Store everything in a structured array
    #Print: The dataset,The number of dimensions (ndim)

    dataset[i] = (cust_id, brand, model, units, amount)

# %%
print("Dataset:\n", dataset)
print("\nNumber of dimensions:", dataset.ndim)
# Out:
# Dataset:
#  [(1001, 'Honda', 'Accord', 4, 104000.)
#  (1002, 'Tesla', 'Model S', 3, 240000.) (1003, 'BMW', 'X3', 4, 168000.)
#  (1004, 'BMW', 'X5', 2, 110000.) (1005, 'Tesla', 'Model 3', 1,  40000.)
#  (1006, 'Tesla', 'Model S', 4, 320000.) (1007, 'BMW', 'X5', 1,  55000.)
#  (1008, 'Toyota', 'Corolla', 3,  60000.)
#  (1009, 'Toyota', 'Camry', 2,  50000.)
#  (1010, 'Toyota', 'Camry', 4, 100000.) (1011, 'Honda', 'CR-V', 5, 140000.)
#  (1012, 'Ford', 'Focus', 2,  40000.) (1013, 'Ford', 'Fiesta', 3,  54000.)
#  (1014, 'Honda', 'CR-V', 2,  56000.)
#  (1015, 'Ford', 'Explorer', 1,  35000.)
#  (1016, 'Honda', 'CR-V', 3,  84000.) (1017, 'BMW', '3 Series', 3, 144000.)
#  (1018, 'Ford', 'Focus', 5, 100000.) (1019, 'Toyota', 'RAV4', 3,  90000.)
#  (1020, 'Toyota', 'RAV4', 5, 150000.)
#  (1021, 'BMW', '3 Series', 1,  48000.)
#  (1022, 'Honda', 'Civic', 3,  66000.)
#  (1023, 'BMW', '3 Series', 5, 240000.)
#  (1024, 'Toyota', 'RAV4', 1,  30000.) (1025, 'Ford', 'Fiesta', 2,  36000.)
#  (1026, 'Ford', 'Focus', 3,  60000.) (1027, 'BMW', 'X5', 3, 165000.)
#  (1028, 'BMW', '3 Series', 5, 240000.)
#  (1029, 'Toyota', 'Corolla', 2,  40000.)
#  (1030, 'Tesla', 'Model S', 2, 160000.)
#  (1031, 'Honda', 'Civic', 1,  22000.)
#  (1032, 'Toyota', 'Camry', 5, 125000.)
#  (1033, 'Tesla', 'Model S', 3, 240000.)
#  (1034, 'Toyota', 'Camry', 4, 100000.)
#  (1035, 'Ford', 'Fiesta', 2,  36000.) (1036, 'Honda', 'Civic', 1,  22000.)
#  (1037, 'Toyota', 'Corolla', 4,  80000.)
#  (1038, 'Honda', 'Civic', 3,  66000.)
#  (1039, 'Tesla', 'Model X', 1,  90000.)
#  (1040, 'Ford', 'Focus', 4,  80000.) (1041, 'BMW', 'X5', 5, 275000.)
#  (1042, 'Tesla', 'Model X', 1,  90000.)
#  (1043, 'Toyota', 'Corolla', 5, 100000.)
#  (1044, 'Honda', 'Accord', 5, 130000.)
#  (1045, 'Tesla', 'Model X', 5, 450000.)
#  (1046, 'Tesla', 'Model X', 3, 270000.)
#  (1047, 'Tesla', 'Model 3', 5, 200000.)
#  (1048, 'Honda', 'Civic', 4,  88000.) (1049, 'BMW', 'X5', 2, 110000.)
#  (1050, 'Tesla', 'Model X', 3, 270000.)
#  (1051, 'BMW', '3 Series', 5, 240000.)
#  (1052, 'Honda', 'Accord', 4, 104000.)
#  (1053, 'Toyota', 'Corolla', 5, 100000.)
#  (1054, 'Ford', 'Explorer', 1,  35000.)
#  (1055, 'Honda', 'CR-V', 2,  56000.) (1056, 'BMW', 'X5', 1,  55000.)
#  (1057, 'Toyota', 'Corolla', 4,  80000.)
#  (1058, 'Toyota', 'Corolla', 4,  80000.)
#  (1059, 'Tesla', 'Model 3', 3, 120000.) (1060, 'BMW', 'X3', 3, 126000.)
#  (1061, 'Toyota', 'RAV4', 5, 150000.)
#  (1062, 'Tesla', 'Model S', 5, 400000.) (1063, 'BMW', 'X5', 1,  55000.)
#  (1064, 'Tesla', 'Model X', 2, 180000.)
#  (1065, 'Tesla', 'Model X', 4, 360000.) (1066, 'BMW', 'X5', 5, 275000.)
#  (1067, 'Toyota', 'RAV4', 1,  30000.) (1068, 'Honda', 'Civic', 2,  44000.)
#  (1069, 'Ford', 'Focus', 5, 100000.)
#  (1070, 'Tesla', 'Model 3', 4, 160000.) (1071, 'BMW', 'X5', 2, 110000.)
#  (1072, 'Toyota', 'Corolla', 3,  60000.)
#  (1073, 'Toyota', 'Corolla', 5, 100000.)
#  (1074, 'Ford', 'Focus', 5, 100000.) (1075, 'Honda', 'Civic', 4,  88000.)
#  (1076, 'Toyota', 'Corolla', 1,  20000.)
#  (1077, 'Tesla', 'Model S', 3, 240000.)
#  (1078, 'Tesla', 'Model S', 4, 320000.)
#  (1079, 'Tesla', 'Model S', 3, 240000.)
#  (1080, 'Honda', 'Civic', 4,  88000.)
#  (1081, 'Ford', 'Explorer', 5, 175000.)
#  (1082, 'Ford', 'Explorer', 1,  35000.)
#  (1083, 'Ford', 'Explorer', 3, 105000.)
#  (1084, 'Toyota', 'Camry', 3,  75000.)
#  (1085, 'Toyota', 'Corolla', 5, 100000.)
#  (1086, 'Tesla', 'Model S', 1,  80000.)
#  (1087, 'Ford', 'Explorer', 3, 105000.)
#  (1088, 'BMW', '3 Series', 3, 144000.)
#  (1089, 'Tesla', 'Model S', 1,  80000.)
#  (1090, 'Ford', 'Fiesta', 1,  18000.)
#  (1091, 'Honda', 'Accord', 3,  78000.)
#  (1092, 'Tesla', 'Model 3', 1,  40000.)
#  (1093, 'Toyota', 'Camry', 3,  75000.)
#  (1094, 'Tesla', 'Model 3', 4, 160000.)
#  (1095, 'Ford', 'Fiesta', 5,  90000.) (1096, 'Toyota', 'RAV4', 2,  60000.)
#  (1097, 'Toyota', 'Camry', 1,  25000.)
#  (1098, 'Honda', 'Civic', 5, 110000.) (1099, 'BMW', 'X3', 1,  42000.)
#  (1100, 'Honda', 'CR-V', 3,  84000.)]
#
# Number of dimensions: 1

# %%
#Total sales amount (sum of Amount column)


total_sales_amount = np.sum(dataset["Amount"])
total_sales_amount
# Out:
# 11866000.0

# %%
#List all unique car brands


unique_brands = np.unique(dataset["CarName"])
unique_brands
# Out:
# array(['BMW', 'Ford', 'Honda', 'Tesla', 'Toyota'], dtype='<U20')

# %%
#Total units sold (sum of Units column)

total_units_sold = np.sum(dataset["Units"])
total_units_sold
# Out:
# 307

# %%
#Total units sold for Tesla only

tesla_units = np.sum(dataset["Units"][dataset["CarName"] == "Tesla"])
tesla_units
# Out:
# 66

# %%
#Total revenue generated by BMW

bmw_revenue = np.sum(dataset["Amount"][dataset["CarName"] == "BMW"])
bmw_revenue
# Out:
# 2602000.0

# %%
#Average units sold for Toyota

toyota_avg_units = np.mean(dataset["Units"][dataset["CarName"] == "Toyota"])
toyota_avg_units
# Out:
# 3.3333333333333335

# %%
#Highest amount among Tesla purchases

tesla_max_amount = np.max(dataset["Amount"][dataset["CarName"] == "Tesla"])
tesla_max_amount
# Out:
# 450000.0

# %%
#Convert structured array → regular 2D NumPy array


dataset_2d = np.column_stack((
    dataset["CustomerID"],
    dataset["CarName"],
    dataset["CarModel"],
    dataset["Units"],
    dataset["Amount"]
))

dataset_2d
# Out:
# array([['1001', 'Honda', 'Accord', '4', '104000.0'],
#        ['1002', 'Tesla', 'Model S', '3', '240000.0'],
#        ['1003', 'BMW', 'X3', '4', '168000.0'],
#        ['1004', 'BMW', 'X5', '2', '110000.0'],
#        ['1005', 'Tesla', 'Model 3', '1', '40000.0'],
#        ['1006', 'Tesla', 'Model S', '4', '320000.0'],
#        ['1007', 'BMW', 'X5', '1', '55000.0'],
#        ['1008', 'Toyota', 'Corolla', '3', '60000.0'],
#        ['1009', 'Toyota', 'Camry', '2', '50000.0'],
#        ['1010', 'Toyota', 'Camry', '4', '100000.0'],
#        ['1011', 'Honda', 'CR-V', '5', '140000.0'],
#        ['1012', 'Ford', 'Focus', '2', '40000.0'],
#        ['1013', 'Ford', 'Fiesta', '3', '54000.0'],
#        ['1014', 'Honda', 'CR-V', '2', '56000.0'],
#        ['1015', 'Ford', 'Explorer', '1', '35000.0'],
#        ['1016', 'Honda', 'CR-V', '3', '84000.0'],
#        ['1017', 'BMW', '3 Series', '3', '144000.0'],
#        ['1018', 'Ford', 'Focus', '5', '100000.0'],
#        ['1019', 'Toyota', 'RAV4', '3', '90000.0'],
#        ['1020', 'Toyota', 'RAV4', '5', '150000.0'],
#        ['1021', 'BMW', '3 Series', '1', '48000.0'],
#        ['1022', 'Honda', 'Civic', '3', '66000.0'],
#        ['1023', 'BMW', '3 Series', '5', '240000.0'],
#        ['1024', 'Toyota', 'RAV4', '1', '30000.0'],
#        ['1025', 'Ford', 'Fiesta', '2', '36000.0'],
#        ['1026', 'Ford', 'Focus', '3', '60000.0'],
#        ['1027', 'BMW', 'X5', '3', '165000.0'],
#        ['1028', 'BMW', '3 Series', '5', '240000.0'],
#        ['1029', 'Toyota', 'Corolla', '2', '40000.0'],
#        ['1030', 'Tesla', 'Model S', '2', '160000.0'],
#        ['1031', 'Honda', 'Civic', '1', '22000.0'],
#        ['1032', 'Toyota', 'Camry', '5', '125000.0'],
#        ['1033', 'Tesla', 'Model S', '3', '240000.0'],
#        ['1034', 'Toyota', 'Camry', '4', '100000.0'],
#        ['1035', 'Ford', 'Fiesta', '2', '36000.0'],
#        ['1036', 'Honda', 'Civic', '1', '22000.0'],
#        ['1037', 'Toyota', 'Corolla', '4', '80000.0'],
#        ['1038', 'Honda', 'Civic', '3', '66000.0'],
#        ['1039', 'Tesla', 'Model X', '1', '90000.0'],
#        ['1040', 'Ford', 'Focus', '4', '80000.0'],
#        ['1041', 'BMW', 'X5', '5', '275000.0'],
#        ['1042', 'Tesla', 'Model X', '1', '90000.0'],
#        ['1043', 'Toyota', 'Corolla', '5', '100000.0'],
#        ['1044', 'Honda', 'Accord', '5', '130000.0'],
#        ['1045', 'Tesla', 'Model X', '5', '450000.0'],
#        ['1046', 'Tesla', 'Model X', '3', '270000.0'],
#        ['1047', 'Tesla', 'Model 3', '5', '200000.0'],
#        ['1048', 'Honda', 'Civic', '4', '88000.0'],
#        ['1049', 'BMW', 'X5', '2', '110000.0'],
#        ['1050', 'Tesla', 'Model X', '3', '270000.0'],
#        ['1051', 'BMW', '3 Series', '5', '240000.0'],
#        ['1052', 'Honda', 'Accord', '4', '104000.0'],
#        ['1053', 'Toyota', 'Corolla', '5', '100000.0'],
#        ['1054', 'Ford', 'Explorer', '1', '35000.0'],
#        ['1055', 'Honda', 'CR-V', '2', '56000.0'],
#        ['1056', 'BMW', 'X5', '1', '55000.0'],
#        ['1057', 'Toyota', 'Corolla', '4', '80000.0'],
#        ['1058', 'Toyota', 'Corolla', '4', '80000.0'],
#        ['1059', 'Tesla', 'Model 3', '3', '120000.0'],
#        ['1060', 'BMW', 'X3', '3', '126000.0'],
#        ['1061', 'Toyota', 'RAV4', '5', '150000.0'],
#        ['1062', 'Tesla', 'Model S', '5', '400000.0'],
#        ['1063', 'BMW', 'X5', '1', '55000.0'],
#        ['1064', 'Tesla', 'Model X', '2', '180000.0'],
#        ['1065', 'Tesla', 'Model X', '4', '360000.0'],
#        ['1066', 'BMW', 'X5', '5', '275000.0'],
#        ['1067', 'Toyota', 'RAV4', '1', '30000.0'],
#        ['1068', 'Honda', 'Civic', '2', '44000.0'],
#        ['1069', 'Ford', 'Focus', '5', '100000.0'],
#        ['1070', 'Tesla', 'Model 3', '4', '160000.0'],
#        ['1071', 'BMW', 'X5', '2', '110000.0'],
#        ['1072', 'Toyota', 'Corolla', '3', '60000.0'],
#        ['1073', 'Toyota', 'Corolla', '5', '100000.0'],
#        ['1074', 'Ford', 'Focus', '5', '100000.0'],
#        ['1075', 'Honda', 'Civic', '4', '88000.0'],
#        ['1076', 'Toyota', 'Corolla', '1', '20000.0'],
#        ['1077', 'Tesla', 'Model S', '3', '240000.0'],
#        ['1078', 'Tesla', 'Model S', '4', '320000.0'],
#        ['1079', 'Tesla', 'Model S', '3', '240000.0'],
#        ['1080', 'Honda', 'Civic', '4', '88000.0'],
#        ['1081', 'Ford', 'Explorer', '5', '175000.0'],
#        ['1082', 'Ford', 'Explorer', '1', '35000.0'],
#        ['1083', 'Ford', 'Explorer', '3', '105000.0'],
#        ['1084', 'Toyota', 'Camry', '3', '75000.0'],
#        ['1085', 'Toyota', 'Corolla', '5', '100000.0'],
#        ['1086', 'Tesla', 'Model S', '1', '80000.0'],
#        ['1087', 'Ford', 'Explorer', '3', '105000.0'],
#        ['1088', 'BMW', '3 Series', '3', '144000.0'],
#        ['1089', 'Tesla', 'Model S', '1', '80000.0'],
#        ['1090', 'Ford', 'Fiesta', '1', '18000.0'],
#        ['1091', 'Honda', 'Accord', '3', '78000.0'],
#        ['1092', 'Tesla', 'Model 3', '1', '40000.0'],
#        ['1093', 'Toyota', 'Camry', '3', '75000.0'],
#        ['1094', 'Tesla', 'Model 3', '4', '160000.0'],
#        ['1095', 'Ford', 'Fiesta', '5', '90000.0'],
#        ['1096', 'Toyota', 'RAV4', '2', '60000.0'],
#        ['1097', 'Toyota', 'Camry', '1', '25000.0'],
#        ['1098', 'Honda', 'Civic', '5', '110000.0'],
#        ['1099', 'BMW', 'X3', '1', '42000.0'],
#        ['1100', 'Honda', 'CR-V', '3', '84000.0']], dtype='<U32')

# %%
#Which brand has maximum total units sold



brands = np.unique(dataset["CarName"])
brand_units = {}

for brand in brands:
    brand_units[brand] = np.sum(dataset["Units"][dataset["CarName"] == brand])

# %%
max_brand = max(brand_units, key=brand_units.get)
max_brand, brand_units[max_brand]
# Out:
# ('Toyota', 80)
